# %% [markdown]
# # stead_convert
#
# Convert STEAD dataset to SP dataset.

# %%
import random
import h5py as h5
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# Modifying sys.path to be able to load project packages
import sys
sys.path.append('../')

# Load project packages
from utils.h5_tools import write_batch

# %%
stead_path = 'C:/data/datasets/STEAD/merge.hdf5'
stead_csv_path = 'C:/data/datasets/STEAD/merge.csv'
save_path = 'C:/data/datasets/STEAD/stead_converted.h5'

# %%
batch_size = 300000
target_trace_length = 400
trarget_half_length = int(target_trace_length/2)

noise_traces_per_base_trace = 2

stdout_step = 1000

P_CODE = 0
S_CODE = 1
NOISE_CODE = 2

# %% [markdown]
# ## CSV columns
#
# network_code,receiver_code,receiver_type,receiver_latitude,receiver_longitude,receiver_elevation_m,p_arrival_sample,
#
# p_status,p_weight,p_travel_sec,s_arrival_sample,s_status,s_weight,source_id,source_origin_time,source_origin_uncertainty_sec,
#
# source_latitude,source_longitude,source_error_sec,source_gap_deg,source_horizontal_uncertainty_km,source_depth_km,
#
# source_depth_uncertainty_km,source_magnitude,source_magnitude_type,source_magnitude_author,source_mechanism_strike_dip_rake,
#
# source_distance_deg,source_distance_km,back_azimuth_deg,snr_db,coda_end_sample,trace_start_time,trace_category,trace_name

# %%
def cut_from_trace(trace, start, length):
    end = start + length
    if end > trace.shape[0]:
        end = trace.shape[0]
        start = end - length
    return trace[start:end].copy()


def get_random_trace_start(length, min_dist, previous=None, max_tries=1000):
    assert max_tries > 0
    if previous is None:
        previous = []
    
    while True:
        max_tries -= 1
        start = random.randint(0, length-min_dist)
        
        passed = True
        for x in previous:
            if int(abs(x-start)) <= min_dist:
                passed = False
                break
        
        if passed:
            return start
        if max_tries == 0:
            return None


def convert_trace(dataset, trace_name, trace_category, p_arrival_sample, s_arrival_sample):
    """
    Converts STEAD trace to one or multiple SP dataset entries (P and S waves or two noise samples).
    """
    trace = dataset[trace_name]

    p_arrival_sample = int(p_arrival_sample) if not np.isnan(p_arrival_sample) else None
    s_arrival_sample = int(s_arrival_sample) if not np.isnan(s_arrival_sample) else None

    is_noise = False
    if (not p_arrival_sample and not s_arrival_sample) or trace_category == 'noise':
        is_noise = True

    X = []
    Y = []

    start_positions = []

    # Cut noise
    if is_noise:
        l = trace.shape[0]
        for _ in range(noise_traces_per_base_trace):
            start = get_random_trace_start(l, target_trace_length, start_positions)
            start_positions.append(start)
            X.append(cut_from_trace(trace, start, target_trace_length))
            Y.append(NOISE_CODE)
        return X, Y

    # Cut events
    if p_arrival_sample:
        X.append(cut_from_trace(trace, max(p_arrival_sample-trarget_half_length, 0), target_trace_length))
        Y.append(P_CODE)
    if s_arrival_sample:
        X.append(cut_from_trace(trace, max(s_arrival_sample-trarget_half_length, 0), target_trace_length))
        Y.append(S_CODE)

    return X, Y

# %%
dataset = h5.File(stead_path, 'r') 
dataset = dataset['data']

df = pd.read_csv(stead_csv_path)
n_traces = len(df); n_traces
# Out:
# C:\Users\syler\.conda\envs\seismo_py_38\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (7,11,13,14,15,18,19,20,21,22,24,25,26,30,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# 1265657

# %%
random.seed(42)

batch_X = np.zeros((batch_size, target_trace_length, 3))
batch_Y = np.zeros(batch_size)

current_idx = 0
total = 0

last_mark = 1

# %%
for i in range(n_traces):
  
    row = df.loc[i]
    trace_name = row['trace_name']
    trace_category = row['trace_category']
    p_arrival_sample = row['p_arrival_sample']
    s_arrival_sample = row['s_arrival_sample']
    X, Y = convert_trace(dataset, trace_name, trace_category, p_arrival_sample, s_arrival_sample)
    
    for j in range(len(X)):
        batch_X[current_idx] = X[j]
        batch_Y[current_idx] = Y[j]
        current_idx += 1
        total += 1
        
        if current_idx >= batch_size:
            write_batch(save_path, 'X', batch_X)
            write_batch(save_path, 'Y', batch_Y)
            print(f'Batch written.. Total of {total} traces.')
            current_idx = 0
            
    if total > last_mark*stdout_step:
        print(f'\tConverted {total} traces.')
        last_mark += 1
            
if current_idx != 0:
    write_batch(save_path, 'X', batch_X[:current_idx])
    write_batch(save_path, 'Y', batch_Y[:current_idx])
# Out:
# 	Converted 1002 traces.
# 	Converted 2002 traces.
# 	Converted 3002 traces.
# 	Converted 4002 traces.
# 	Converted 5002 traces.
# 	Converted 6002 traces.
# 	Converted 7002 traces.
# 	Converted 8002 traces.
# 	Converted 9002 traces.
# 	Converted 10002 traces.
# 	Converted 11002 traces.
# 	Converted 12002 traces.
# 	Converted 13002 traces.
# 	Converted 14002 traces.
# 	Converted 15002 traces.
# 	Converted 16002 traces.
# 	Converted 17002 traces.
# 	Converted 18002 traces.
# 	Converted 19002 traces.
# 	Converted 20002 traces.
# 	Converted 21002 traces.
# 	Converted 22002 traces.
# 	Converted 23002 traces.
# 	Converted 24002 traces.
# 	Converted 25002 traces.
# 	Converted 26002 traces.
# 	Converted 27002 traces.
# 	Converted 28002 traces.
# 	Converted 29002 traces.
# 	Converted 30002 traces.
# 	Converted 31002 traces.
# 	Converted 32002 traces.
# 	Converted 33002 traces.
# 	Converted 34002 traces.
# 	Converted 35002 traces.
# 	Converted 36002 traces.
# 	Converted 37002 traces.
# 	Converted 38002 traces.
# 	Converted 39002 traces.
# 	Converted 40002 traces.
# 	Converted 41002 traces.
# 	Converted 42002 traces.
# 	Converted 43002 traces.
# 	Converted 44002 traces.
# 	Converted 45002 traces.
# 	Converted 46002 traces.
# 	Converted 47002 traces.
# 	Converted 48002 traces.
# 	Converted 49002 traces.
# 	Converted 50002 traces.
# 	Converted 51002 traces.
# 	Converted 52002 traces.
# 	Converted 53002 traces.
# 	Converted 54002 traces.
# 	Converted 55002 traces.
# 	Converted 56002 traces.
# 	Converted 57002 traces.
# 	Converted 58002 traces.
# 	Converted 59002 traces.
# 	Converted 60002 traces.
# 	Converted 61002 traces.
# 	Converted 62002 traces.
# 	Converted 63002 traces.
# 	Converted 64002 traces.
# 	Converted 65002 traces.
# 	Converted 66002 traces.
# 	Converted 67002 traces.
# 	Converted 68002 traces.
# 	Converted 69002 traces.
# 	Converted 70002 traces.
# 	Converted 71002 traces.
# 	Converted 72002 traces.
# 	Converted 73002 traces.
# 	Converted 74002 traces.
# 	Converted 75002 traces.
# 	Converted 76002 traces.
# 	Converted 77002 traces.
# 	Converted 78002 traces.
# 	Converted 79002 traces.
# 	Converted 80002 traces.
# 	Converted 81002 traces.
# 	Converted 82002 traces.
# 	Converted 83002 traces.
# 	Converted 84002 traces.
# 	Converted 85002 traces.
# 	Converted 86002 traces.
# 	Converted 87002 traces.
# 	Converted 88002 traces.
# 	Converted 89002 traces.
# 	Converted 90002 traces.
# 	Converted 91002 traces.
# 	Converted 92002 traces.
# 	Converted 93002 traces.
# 	Converted 94002 traces.
# 	Converted 95002 traces.
# 	Converted 96002 traces.
# 	Converted 97002 traces.
# 	Converted 98002 traces.
# 	Converted 99002 traces.
# 	Converted 100002 traces.
# 	Converted 101002 traces.
# 	Converted 102002 traces.
# 	Converted 103002 traces.
# 	Converted 104002 traces.
# 	Converted 105002 traces.
# 	Converted 106002 traces.
# 	Converted 107002 traces.
# 	Converted 108002 traces.
# 	Converted 109002 traces.
# 	Converted 110002 traces.
# 	Converted 111002 traces.
# 	Converted 112002 traces.
# 	Converted 113002 traces.
# 	Converted 114002 traces.
# 	Converted 115002 traces.
# 	Converted 116002 traces.
# 	Converted 117002 traces.
# 	Converted 118002 traces.
# 	Converted 119002 traces.
# 	Converted 120002 traces.
# 	Converted 121002 traces.
# 	Converted 122002 traces.
# 	Converted 123002 traces.
# 	Converted 124002 traces.
# 	Converted 125002 traces.
# 	Converted 126002 traces.
# 	Converted 127002 traces.
# 	Converted 128002 traces.
# 	Converted 129002 traces.
# 	Converted 130002 traces.
# 	Converted 131002 traces.
# 	Converted 132002 traces.
# 	Converted 133002 traces.
# 	Converted 134002 traces.
# 	Converted 135002 traces.
# 	Converted 136002 traces.
# 	Converted 137002 traces.
# 	Converted 138002 traces.
# 	Converted 139002 traces.
# 	Converted 140002 traces.
# 	Converted 141002 traces.
# 	Converted 142002 traces.
# 	Converted 143002 traces.
# 	Converted 144002 traces.
# 	Converted 145002 traces.
# 	Converted 146002 traces.
# 	Converted 147002 traces.
# 	Converted 148002 traces.
# 	Converted 149002 traces.
# 	Converted 150002 traces.
# 	Converted 151002 traces.
# 	Converted 152002 traces.
# 	Converted 153002 traces.
# 	Converted 154002 traces.
# 	Converted 155002 traces.
# 	Converted 156002 traces.
# 	Converted 157002 traces.
# 	Converted 158002 traces.
# 	Converted 159002 traces.
# 	Converted 160002 traces.
# 	Converted 161002 traces.
# 	Converted 162002 traces.
# 	Converted 163002 traces.
# 	Converted 164002 traces.
# 	Converted 165002 traces.
# 	Converted 166002 traces.
# 	Converted 167002 traces.
# 	Converted 168002 traces.
# 	Converted 169002 traces.
# 	Converted 170002 traces.
# 	Converted 171002 traces.
# 	Converted 172002 traces.
# 	Converted 173002 traces.
# 	Converted 174002 traces.
# 	Converted 175002 traces.
# 	Converted 176002 traces.
# 	Converted 177002 traces.
# 	Converted 178002 traces.
# 	Converted 179002 traces.
# 	Converted 180002 traces.
# 	Converted 181002 traces.
# 	Converted 182002 traces.
# 	Converted 183002 traces.
# 	Converted 184002 traces.
# 	Converted 185002 traces.
# 	Converted 186002 traces.
# 	Converted 187002 traces.
# 	Converted 188002 traces.
# 	Converted 189002 traces.
# 	Converted 190002 traces.
# 	Converted 191002 traces.
# 	Converted 192002 traces.
# 	Converted 193002 traces.
# 	Converted 194002 traces.
# 	Converted 195002 traces.
# 	Converted 196002 traces.
# 	Converted 197002 traces.
# 	Converted 198002 traces.
# 	Converted 199002 traces.
# 	Converted 200002 traces.
# 	Converted 201002 traces.
# 	Converted 202002 traces.
# 	Converted 203002 traces.
# 	Converted 204002 traces.
# 	Converted 205002 traces.
# 	Converted 206002 traces.
# 	Converted 207002 traces.
# 	Converted 208002 traces.
# 	Converted 209002 traces.
# 	Converted 210002 traces.
# 	Converted 211002 traces.
# 	Converted 212002 traces.
# 	Converted 213002 traces.
# 	Converted 214002 traces.
# 	Converted 215002 traces.
# 	Converted 216002 traces.
# 	Converted 217002 traces.
# 	Converted 218002 traces.
# 	Converted 219002 traces.
# 	Converted 220002 traces.
# 	Converted 221002 traces.
# 	Converted 222002 traces.
# 	Converted 223002 traces.
# 	Converted 224002 traces.
# 	Converted 225002 traces.
# 	Converted 226002 traces.
# 	Converted 227002 traces.
# 	Converted 228002 traces.
# 	Converted 229002 traces.
# 	Converted 230002 traces.
# 	Converted 231002 traces.
# 	Converted 232002 traces.
# 	Converted 233002 traces.
# 	Converted 234002 traces.
# 	Converted 235002 traces.
# 	Converted 236002 traces.
# 	Converted 237002 traces.
# 	Converted 238002 traces.
# 	Converted 239002 traces.
# 	Converted 240002 traces.
# 	Converted 241002 traces.
# 	Converted 242002 traces.
# 	Converted 243002 traces.
# 	Converted 244002 traces.
# 	Converted 245002 traces.
# 	Converted 246002 traces.
# 	Converted 247002 traces.
# 	Converted 248002 traces.
# 	Converted 249002 traces.
# 	Converted 250002 traces.
# 	Converted 251002 traces.
# 	Converted 252002 traces.
# 	Converted 253002 traces.
# 	Converted 254002 traces.
# 	Converted 255002 traces.
# 	Converted 256002 traces.
# 	Converted 257002 traces.
# 	Converted 258002 traces.
# 	Converted 259002 traces.
# 	Converted 260002 traces.
# 	Converted 261002 traces.
# 	Converted 262002 traces.
# 	Converted 263002 traces.
# 	Converted 264002 traces.
# 	Converted 265002 traces.
# 	Converted 266002 traces.
# 	Converted 267002 traces.
# 	Converted 268002 traces.
# 	Converted 269002 traces.
# 	Converted 270002 traces.
# 	Converted 271002 traces.
# 	Converted 272002 traces.
# 	Converted 273002 traces.
# 	Converted 274002 traces.
# 	Converted 275002 traces.
# 	Converted 276002 traces.
# 	Converted 277002 traces.
# 	Converted 278002 traces.
# 	Converted 279002 traces.
# 	Converted 280002 traces.
# 	Converted 281002 traces.
# 	Converted 282002 traces.
# 	Converted 283002 traces.
# 	Converted 284002 traces.
# 	Converted 285002 traces.
# 	Converted 286002 traces.
# 	Converted 287002 traces.
# 	Converted 288002 traces.
# 	Converted 289002 traces.
# 	Converted 290002 traces.
# 	Converted 291002 traces.
# 	Converted 292002 traces.
# 	Converted 293002 traces.
# 	Converted 294002 traces.
# 	Converted 295002 traces.
# 	Converted 296002 traces.
# 	Converted 297002 traces.
# 	Converted 298002 traces.
# 	Converted 299002 traces.
# Batch written.. Total of 300000 traces.
# 	Converted 300002 traces.
# 	Converted 301002 traces.
# 	Converted 302002 traces.
# 	Converted 303002 traces.
# 	Converted 304002 traces.
# 	Converted 305002 traces.
# 	Converted 306002 traces.
# 	Converted 307002 traces.
# 	Converted 308002 traces.
# 	Converted 309002 traces.
# 	Converted 310002 traces.
# 	Converted 311002 traces.
# 	Converted 312002 traces.
# 	Converted 313002 traces.
# 	Converted 314002 traces.
# 	Converted 315002 traces.
# 	Converted 316002 traces.
# 	Converted 317002 traces.
# 	Converted 318002 traces.
# 	Converted 319002 traces.
# 	Converted 320002 traces.
# 	Converted 321002 traces.
# 	Converted 322002 traces.
# 	Converted 323002 traces.
# 	Converted 324002 traces.
# 	Converted 325002 traces.
# 	Converted 326002 traces.
# 	Converted 327002 traces.
# 	Converted 328002 traces.
# 	Converted 329002 traces.
# 	Converted 330002 traces.
# 	Converted 331002 traces.
# 	Converted 332002 traces.
# 	Converted 333002 traces.
# 	Converted 334002 traces.
# 	Converted 335002 traces.
# 	Converted 336002 traces.
# 	Converted 337002 traces.
# 	Converted 338002 traces.
# 	Converted 339002 traces.
# 	Converted 340002 traces.
# 	Converted 341002 traces.
# 	Converted 342002 traces.
# 	Converted 343002 traces.
# 	Converted 344002 traces.
# 	Converted 345002 traces.
# 	Converted 346002 traces.
# 	Converted 347002 traces.
# 	Converted 348002 traces.
# 	Converted 349002 traces.
# 	Converted 350002 traces.
# 	Converted 351002 traces.
# 	Converted 352002 traces.
# 	Converted 353002 traces.
# 	Converted 354002 traces.
# 	Converted 355002 traces.
# 	Converted 356002 traces.
# 	Converted 357002 traces.
# 	Converted 358002 traces.
# 	Converted 359002 traces.
# 	Converted 360002 traces.
# 	Converted 361002 traces.
# 	Converted 362002 traces.
# 	Converted 363002 traces.
# 	Converted 364002 traces.
# 	Converted 365002 traces.
# 	Converted 366002 traces.
# 	Converted 367002 traces.
# 	Converted 368002 traces.
# 	Converted 369002 traces.
# 	Converted 370002 traces.
# 	Converted 371002 traces.
# 	Converted 372002 traces.
# 	Converted 373002 traces.
# 	Converted 374002 traces.
# 	Converted 375002 traces.
# 	Converted 376002 traces.
# 	Converted 377002 traces.
# 	Converted 378002 traces.
# 	Converted 379002 traces.
# 	Converted 380002 traces.
# 	Converted 381002 traces.
# 	Converted 382002 traces.
# 	Converted 383002 traces.
# 	Converted 384002 traces.
# 	Converted 385002 traces.
# 	Converted 386002 traces.
# 	Converted 387002 traces.
# 	Converted 388002 traces.
# 	Converted 389002 traces.
# 	Converted 390002 traces.
# 	Converted 391002 traces.
# 	Converted 392002 traces.
# 	Converted 393002 traces.
# 	Converted 394002 traces.
# 	Converted 395002 traces.
# 	Converted 396002 traces.
# 	Converted 397002 traces.
# 	Converted 398002 traces.
# 	Converted 399002 traces.
# 	Converted 400002 traces.
# 	Converted 401002 traces.
# 	Converted 402002 traces.
# 	Converted 403002 traces.
# 	Converted 404002 traces.
# 	Converted 405002 traces.
# 	Converted 406002 traces.
# 	Converted 407002 traces.
# 	Converted 408002 traces.
# 	Converted 409002 traces.
# 	Converted 410002 traces.
# 	Converted 411002 traces.
# 	Converted 412002 traces.
# 	Converted 413002 traces.
# 	Converted 414002 traces.
# 	Converted 415002 traces.
# 	Converted 416002 traces.
# 	Converted 417002 traces.
# 	Converted 418002 traces.
# 	Converted 419002 traces.
# 	Converted 420002 traces.
# 	Converted 421002 traces.
# 	Converted 422002 traces.
# 	Converted 423002 traces.
# 	Converted 424002 traces.
# 	Converted 425002 traces.
# 	Converted 426002 traces.
# 	Converted 427002 traces.
# 	Converted 428002 traces.
# 	Converted 429002 traces.
# 	Converted 430002 traces.
# 	Converted 431002 traces.
# 	Converted 432002 traces.
# 	Converted 433002 traces.
# 	Converted 434002 traces.
# 	Converted 435002 traces.
# 	Converted 436002 traces.
# 	Converted 437002 traces.
# 	Converted 438002 traces.
# 	Converted 439002 traces.
# 	Converted 440002 traces.
# 	Converted 441002 traces.
# 	Converted 442002 traces.
# 	Converted 443002 traces.
# 	Converted 444002 traces.
# 	Converted 445002 traces.
# 	Converted 446002 traces.
# 	Converted 447002 traces.
# 	Converted 448002 traces.
# 	Converted 449002 traces.
# 	Converted 450002 traces.
# 	Converted 451002 traces.
# 	Converted 452002 traces.
# 	Converted 453002 traces.
# 	Converted 454002 traces.
# 	Converted 455002 traces.
# 	Converted 456002 traces.
# 	Converted 457002 traces.
# 	Converted 458002 traces.
# 	Converted 459002 traces.
# 	Converted 460002 traces.
# 	Converted 461002 traces.
# 	Converted 462002 traces.
# 	Converted 463002 traces.
# 	Converted 464002 traces.
# 	Converted 465002 traces.
# 	Converted 466002 traces.
# 	Converted 467002 traces.
# 	Converted 468002 traces.
# 	Converted 469002 traces.
# 	Converted 470002 traces.
# 	Converted 471002 traces.
# 	Converted 472002 traces.
# 	Converted 473002 traces.
# 	Converted 474002 traces.
# 	Converted 475002 traces.
# 	Converted 476002 traces.
# 	Converted 477002 traces.
# 	Converted 478002 traces.
# 	Converted 479002 traces.
# 	Converted 480002 traces.
# 	Converted 481002 traces.
# 	Converted 482002 traces.
# 	Converted 483002 traces.
# 	Converted 484002 traces.
# 	Converted 485002 traces.
# 	Converted 486002 traces.
# 	Converted 487002 traces.
# 	Converted 488002 traces.
# 	Converted 489002 traces.
# 	Converted 490002 traces.
# 	Converted 491002 traces.
# 	Converted 492002 traces.
# 	Converted 493002 traces.
# 	Converted 494002 traces.
# 	Converted 495002 traces.
# 	Converted 496002 traces.
# 	Converted 497002 traces.
# 	Converted 498002 traces.
# 	Converted 499002 traces.
# 	Converted 500002 traces.
# 	Converted 501002 traces.
# 	Converted 502002 traces.
# 	Converted 503002 traces.
# 	Converted 504002 traces.
# 	Converted 505002 traces.
# 	Converted 506002 traces.
# 	Converted 507002 traces.
# 	Converted 508002 traces.
# 	Converted 509002 traces.
# 	Converted 510002 traces.
# 	Converted 511002 traces.
# 	Converted 512002 traces.
# 	Converted 513002 traces.
# 	Converted 514002 traces.
# 	Converted 515002 traces.
# 	Converted 516002 traces.
# 	Converted 517002 traces.
# 	Converted 518002 traces.
# 	Converted 519002 traces.
# 	Converted 520002 traces.
# 	Converted 521002 traces.
# 	Converted 522002 traces.
# 	Converted 523002 traces.
# 	Converted 524002 traces.
# 	Converted 525002 traces.
# 	Converted 526002 traces.
# 	Converted 527002 traces.
# 	Converted 528002 traces.
# 	Converted 529002 traces.
# 	Converted 530002 traces.
# 	Converted 531002 traces.
# 	Converted 532002 traces.
# 	Converted 533002 traces.
# 	Converted 534002 traces.
# 	Converted 535002 traces.
# 	Converted 536002 traces.
# 	Converted 537002 traces.
# 	Converted 538002 traces.
# 	Converted 539002 traces.
# 	Converted 540002 traces.
# 	Converted 541002 traces.
# 	Converted 542002 traces.
# 	Converted 543002 traces.
# 	Converted 544002 traces.
# 	Converted 545002 traces.
# 	Converted 546002 traces.
# 	Converted 547002 traces.
# 	Converted 548002 traces.
# 	Converted 549002 traces.
# 	Converted 550002 traces.
# 	Converted 551002 traces.
# 	Converted 552002 traces.
# 	Converted 553002 traces.
# 	Converted 554002 traces.
# 	Converted 555002 traces.
# 	Converted 556002 traces.
# 	Converted 557002 traces.
# 	Converted 558002 traces.
# 	Converted 559002 traces.
# 	Converted 560002 traces.
# 	Converted 561002 traces.
# 	Converted 562002 traces.
# 	Converted 563002 traces.
# 	Converted 564002 traces.
# 	Converted 565002 traces.
# 	Converted 566002 traces.
# 	Converted 567002 traces.
# 	Converted 568002 traces.
# 	Converted 569002 traces.
# 	Converted 570002 traces.
# 	Converted 571002 traces.
# 	Converted 572002 traces.
# 	Converted 573002 traces.
# 	Converted 574002 traces.
# 	Converted 575002 traces.
# 	Converted 576002 traces.
# 	Converted 577002 traces.
# 	Converted 578002 traces.
# 	Converted 579002 traces.
# 	Converted 580002 traces.
# 	Converted 581002 traces.
# 	Converted 582002 traces.
# 	Converted 583002 traces.
# 	Converted 584002 traces.
# 	Converted 585002 traces.
# 	Converted 586002 traces.
# 	Converted 587002 traces.
# 	Converted 588002 traces.
# 	Converted 589002 traces.
# 	Converted 590002 traces.
# 	Converted 591002 traces.
# 	Converted 592002 traces.
# 	Converted 593002 traces.
# 	Converted 594002 traces.
# 	Converted 595002 traces.
# 	Converted 596002 traces.
# 	Converted 597002 traces.
# 	Converted 598002 traces.
# 	Converted 599002 traces.
# Batch written.. Total of 600000 traces.
# 	Converted 600002 traces.
# 	Converted 601002 traces.
# 	Converted 602002 traces.
# 	Converted 603002 traces.
# 	Converted 604002 traces.
# 	Converted 605002 traces.
# 	Converted 606002 traces.
# 	Converted 607002 traces.
# 	Converted 608002 traces.
# 	Converted 609002 traces.
# 	Converted 610002 traces.
# 	Converted 611002 traces.
# 	Converted 612002 traces.
# 	Converted 613002 traces.
# 	Converted 614002 traces.
# 	Converted 615002 traces.
# 	Converted 616002 traces.
# 	Converted 617002 traces.
# 	Converted 618002 traces.
# 	Converted 619002 traces.
# 	Converted 620002 traces.
# 	Converted 621002 traces.
# 	Converted 622002 traces.
# 	Converted 623002 traces.
# 	Converted 624002 traces.
# 	Converted 625002 traces.
# 	Converted 626002 traces.
# 	Converted 627002 traces.
# 	Converted 628002 traces.
# 	Converted 629002 traces.
# 	Converted 630002 traces.
# 	Converted 631002 traces.
# 	Converted 632002 traces.
# 	Converted 633002 traces.
# 	Converted 634002 traces.
# 	Converted 635002 traces.
# 	Converted 636002 traces.
# 	Converted 637002 traces.
# 	Converted 638002 traces.
# 	Converted 639002 traces.
# 	Converted 640002 traces.
# 	Converted 641002 traces.
# 	Converted 642002 traces.
# 	Converted 643002 traces.
# 	Converted 644002 traces.
# 	Converted 645002 traces.
# 	Converted 646002 traces.
# 	Converted 647002 traces.
# 	Converted 648002 traces.
# 	Converted 649002 traces.
# 	Converted 650002 traces.
# 	Converted 651002 traces.
# 	Converted 652002 traces.
# 	Converted 653002 traces.
# 	Converted 654002 traces.
# 	Converted 655002 traces.
# 	Converted 656002 traces.
# 	Converted 657002 traces.
# 	Converted 658002 traces.
# 	Converted 659002 traces.
# 	Converted 660002 traces.
# 	Converted 661002 traces.
# 	Converted 662002 traces.
# 	Converted 663002 traces.
# 	Converted 664002 traces.
# 	Converted 665002 traces.
# 	Converted 666002 traces.
# 	Converted 667002 traces.
# 	Converted 668002 traces.
# 	Converted 669002 traces.
# 	Converted 670002 traces.
# 	Converted 671002 traces.
# 	Converted 672002 traces.
# 	Converted 673002 traces.
# 	Converted 674002 traces.
# 	Converted 675002 traces.
# 	Converted 676002 traces.
# 	Converted 677002 traces.
# 	Converted 678002 traces.
# 	Converted 679002 traces.
# 	Converted 680002 traces.
# 	Converted 681002 traces.
# 	Converted 682002 traces.
# 	Converted 683002 traces.
# 	Converted 684002 traces.
# 	Converted 685002 traces.
# 	Converted 686002 traces.
# 	Converted 687002 traces.
# 	Converted 688002 traces.
# 	Converted 689002 traces.
# 	Converted 690002 traces.
# 	Converted 691002 traces.
# 	Converted 692002 traces.
# 	Converted 693002 traces.
# 	Converted 694002 traces.
# 	Converted 695002 traces.
# 	Converted 696002 traces.
# 	Converted 697002 traces.
# 	Converted 698002 traces.
# 	Converted 699002 traces.
# 	Converted 700002 traces.
# 	Converted 701002 traces.
# 	Converted 702002 traces.
# 	Converted 703002 traces.
# 	Converted 704002 traces.
# 	Converted 705002 traces.
# 	Converted 706002 traces.
# 	Converted 707002 traces.
# 	Converted 708002 traces.
# 	Converted 709002 traces.
# 	Converted 710002 traces.
# 	Converted 711002 traces.
# 	Converted 712002 traces.
# 	Converted 713002 traces.
# 	Converted 714002 traces.
# 	Converted 715002 traces.
# 	Converted 716002 traces.
# 	Converted 717002 traces.
# 	Converted 718002 traces.
# 	Converted 719002 traces.
# 	Converted 720002 traces.
# 	Converted 721002 traces.
# 	Converted 722002 traces.
# 	Converted 723002 traces.
# 	Converted 724002 traces.
# 	Converted 725002 traces.
# 	Converted 726002 traces.
# 	Converted 727002 traces.
# 	Converted 728002 traces.
# 	Converted 729002 traces.
# 	Converted 730002 traces.
# 	Converted 731002 traces.
# 	Converted 732002 traces.
# 	Converted 733002 traces.
# 	Converted 734002 traces.
# 	Converted 735002 traces.
# 	Converted 736002 traces.
# 	Converted 737002 traces.
# 	Converted 738002 traces.
# 	Converted 739002 traces.
# 	Converted 740002 traces.
# 	Converted 741002 traces.
# 	Converted 742002 traces.
# 	Converted 743002 traces.
# 	Converted 744002 traces.
# 	Converted 745002 traces.
# 	Converted 746002 traces.
# 	Converted 747002 traces.
# 	Converted 748002 traces.
# 	Converted 749002 traces.
# 	Converted 750002 traces.
# 	Converted 751002 traces.
# 	Converted 752002 traces.
# 	Converted 753002 traces.
# 	Converted 754002 traces.
# 	Converted 755002 traces.
# 	Converted 756002 traces.
# 	Converted 757002 traces.
# 	Converted 758002 traces.
# 	Converted 759002 traces.
# 	Converted 760002 traces.
# 	Converted 761002 traces.
# 	Converted 762002 traces.
# 	Converted 763002 traces.
# 	Converted 764002 traces.
# 	Converted 765002 traces.
# 	Converted 766002 traces.
# 	Converted 767002 traces.
# 	Converted 768002 traces.
# 	Converted 769002 traces.
# 	Converted 770002 traces.
# 	Converted 771002 traces.
# 	Converted 772002 traces.
# 	Converted 773002 traces.
# 	Converted 774002 traces.
# 	Converted 775002 traces.
# 	Converted 776002 traces.
# 	Converted 777002 traces.
# 	Converted 778002 traces.
# 	Converted 779002 traces.
# 	Converted 780002 traces.
# 	Converted 781002 traces.
# 	Converted 782002 traces.
# 	Converted 783002 traces.
# 	Converted 784002 traces.
# 	Converted 785002 traces.
# 	Converted 786002 traces.
# 	Converted 787002 traces.
# 	Converted 788002 traces.
# 	Converted 789002 traces.
# 	Converted 790002 traces.
# 	Converted 791002 traces.
# 	Converted 792002 traces.
# 	Converted 793002 traces.
# 	Converted 794002 traces.
# 	Converted 795002 traces.
# 	Converted 796002 traces.
# 	Converted 797002 traces.
# 	Converted 798002 traces.
# 	Converted 799002 traces.
# 	Converted 800002 traces.
# 	Converted 801002 traces.
# 	Converted 802002 traces.
# 	Converted 803002 traces.
# 	Converted 804002 traces.
# 	Converted 805002 traces.
# 	Converted 806002 traces.
# 	Converted 807002 traces.
# 	Converted 808002 traces.
# 	Converted 809002 traces.
# 	Converted 810002 traces.
# 	Converted 811002 traces.
# 	Converted 812002 traces.
# 	Converted 813002 traces.
# 	Converted 814002 traces.
# 	Converted 815002 traces.
# 	Converted 816002 traces.
# 	Converted 817002 traces.
# 	Converted 818002 traces.
# 	Converted 819002 traces.
# 	Converted 820002 traces.
# 	Converted 821002 traces.
# 	Converted 822002 traces.
# 	Converted 823002 traces.
# 	Converted 824002 traces.
# 	Converted 825002 traces.
# 	Converted 826002 traces.
# 	Converted 827002 traces.
# 	Converted 828002 traces.
# 	Converted 829002 traces.
# 	Converted 830002 traces.
# 	Converted 831002 traces.
# 	Converted 832002 traces.
# 	Converted 833002 traces.
# 	Converted 834002 traces.
# 	Converted 835002 traces.
# 	Converted 836002 traces.
# 	Converted 837002 traces.
# 	Converted 838002 traces.
# 	Converted 839002 traces.
# 	Converted 840002 traces.
# 	Converted 841002 traces.
# 	Converted 842002 traces.
# 	Converted 843002 traces.
# 	Converted 844002 traces.
# 	Converted 845002 traces.
# 	Converted 846002 traces.
# 	Converted 847002 traces.
# 	Converted 848002 traces.
# 	Converted 849002 traces.
# 	Converted 850002 traces.
# 	Converted 851002 traces.
# 	Converted 852002 traces.
# 	Converted 853002 traces.
# 	Converted 854002 traces.
# 	Converted 855002 traces.
# 	Converted 856002 traces.
# 	Converted 857002 traces.
# 	Converted 858002 traces.
# 	Converted 859002 traces.
# 	Converted 860002 traces.
# 	Converted 861002 traces.
# 	Converted 862002 traces.
# 	Converted 863002 traces.
# 	Converted 864002 traces.
# 	Converted 865002 traces.
# 	Converted 866002 traces.
# 	Converted 867002 traces.
# 	Converted 868002 traces.
# 	Converted 869002 traces.
# 	Converted 870002 traces.
# 	Converted 871002 traces.
# 	Converted 872002 traces.
# 	Converted 873002 traces.
# 	Converted 874002 traces.
# 	Converted 875002 traces.
# 	Converted 876002 traces.
# 	Converted 877002 traces.
# 	Converted 878002 traces.
# 	Converted 879002 traces.
# 	Converted 880002 traces.
# 	Converted 881002 traces.
# 	Converted 882002 traces.
# 	Converted 883002 traces.
# 	Converted 884002 traces.
# 	Converted 885002 traces.
# 	Converted 886002 traces.
# 	Converted 887002 traces.
# 	Converted 888002 traces.
# 	Converted 889002 traces.
# 	Converted 890002 traces.
# 	Converted 891002 traces.
# 	Converted 892002 traces.
# 	Converted 893002 traces.
# 	Converted 894002 traces.
# 	Converted 895002 traces.
# 	Converted 896002 traces.
# 	Converted 897002 traces.
# 	Converted 898002 traces.
# 	Converted 899002 traces.
# Batch written.. Total of 900000 traces.
# 	Converted 900002 traces.
# 	Converted 901002 traces.
# 	Converted 902002 traces.
# 	Converted 903002 traces.
# 	Converted 904002 traces.
# 	Converted 905002 traces.
# 	Converted 906002 traces.
# 	Converted 907002 traces.
# 	Converted 908002 traces.
# 	Converted 909002 traces.
# 	Converted 910002 traces.
# 	Converted 911002 traces.
# 	Converted 912002 traces.
# 	Converted 913002 traces.
# 	Converted 914002 traces.
# 	Converted 915002 traces.
# 	Converted 916002 traces.
# 	Converted 917002 traces.
# 	Converted 918002 traces.
# 	Converted 919002 traces.
# 	Converted 920002 traces.
# 	Converted 921002 traces.
# 	Converted 922002 traces.
# 	Converted 923002 traces.
# 	Converted 924002 traces.
# 	Converted 925002 traces.
# 	Converted 926002 traces.
# 	Converted 927002 traces.
# 	Converted 928002 traces.
# 	Converted 929002 traces.
# 	Converted 930002 traces.
# 	Converted 931002 traces.
# 	Converted 932002 traces.
# 	Converted 933002 traces.
# 	Converted 934002 traces.
# 	Converted 935002 traces.
# 	Converted 936002 traces.
# 	Converted 937002 traces.
# 	Converted 938002 traces.
# 	Converted 939002 traces.
# 	Converted 940002 traces.
# 	Converted 941002 traces.
# 	Converted 942002 traces.
# 	Converted 943002 traces.
# 	Converted 944002 traces.
# 	Converted 945002 traces.
# 	Converted 946002 traces.
# 	Converted 947002 traces.
# 	Converted 948002 traces.
# 	Converted 949002 traces.
# 	Converted 950002 traces.
# 	Converted 951002 traces.
# 	Converted 952002 traces.
# 	Converted 953002 traces.
# 	Converted 954002 traces.
# 	Converted 955002 traces.
# 	Converted 956002 traces.
# 	Converted 957002 traces.
# 	Converted 958002 traces.
# 	Converted 959002 traces.
# 	Converted 960002 traces.
# 	Converted 961002 traces.
# 	Converted 962002 traces.
# 	Converted 963002 traces.
# 	Converted 964002 traces.
# 	Converted 965002 traces.
# 	Converted 966002 traces.
# 	Converted 967002 traces.
# 	Converted 968002 traces.
# 	Converted 969002 traces.
# 	Converted 970002 traces.
# 	Converted 971002 traces.
# 	Converted 972002 traces.
# 	Converted 973002 traces.
# 	Converted 974002 traces.
# 	Converted 975002 traces.
# 	Converted 976002 traces.
# 	Converted 977002 traces.
# 	Converted 978002 traces.
# 	Converted 979002 traces.
# 	Converted 980002 traces.
# 	Converted 981002 traces.
# 	Converted 982002 traces.
# 	Converted 983002 traces.
# 	Converted 984002 traces.
# 	Converted 985002 traces.
# 	Converted 986002 traces.
# 	Converted 987002 traces.
# 	Converted 988002 traces.
# 	Converted 989002 traces.
# 	Converted 990002 traces.
# 	Converted 991002 traces.
# 	Converted 992002 traces.
# 	Converted 993002 traces.
# 	Converted 994002 traces.
# 	Converted 995002 traces.
# 	Converted 996002 traces.
# 	Converted 997002 traces.
# 	Converted 998002 traces.
# 	Converted 999002 traces.
# 	Converted 1000002 traces.
# 	Converted 1001002 traces.
# 	Converted 1002002 traces.
# 	Converted 1003002 traces.
# 	Converted 1004002 traces.
# 	Converted 1005002 traces.
# 	Converted 1006002 traces.
# 	Converted 1007002 traces.
# 	Converted 1008002 traces.
# 	Converted 1009002 traces.
# 	Converted 1010002 traces.
# 	Converted 1011002 traces.
# 	Converted 1012002 traces.
# 	Converted 1013002 traces.
# 	Converted 1014002 traces.
# 	Converted 1015002 traces.
# 	Converted 1016002 traces.
# 	Converted 1017002 traces.
# 	Converted 1018002 traces.
# 	Converted 1019002 traces.
# 	Converted 1020002 traces.
# 	Converted 1021002 traces.
# 	Converted 1022002 traces.
# 	Converted 1023002 traces.
# 	Converted 1024002 traces.
# 	Converted 1025002 traces.
# 	Converted 1026002 traces.
# 	Converted 1027002 traces.
# 	Converted 1028002 traces.
# 	Converted 1029002 traces.
# 	Converted 1030002 traces.
# 	Converted 1031002 traces.
# 	Converted 1032002 traces.
# 	Converted 1033002 traces.
# 	Converted 1034002 traces.
# 	Converted 1035002 traces.
# 	Converted 1036002 traces.
# 	Converted 1037002 traces.
# 	Converted 1038002 traces.
# 	Converted 1039002 traces.
# 	Converted 1040002 traces.
# 	Converted 1041002 traces.
# 	Converted 1042002 traces.
# 	Converted 1043002 traces.
# 	Converted 1044002 traces.
# 	Converted 1045002 traces.
# 	Converted 1046002 traces.
# 	Converted 1047002 traces.
# 	Converted 1048002 traces.
# 	Converted 1049002 traces.
# 	Converted 1050002 traces.
# 	Converted 1051002 traces.
# 	Converted 1052002 traces.
# 	Converted 1053002 traces.
# 	Converted 1054002 traces.
# 	Converted 1055002 traces.
# 	Converted 1056002 traces.
# 	Converted 1057002 traces.
# 	Converted 1058002 traces.
# 	Converted 1059002 traces.
# 	Converted 1060002 traces.
# 	Converted 1061002 traces.
# 	Converted 1062002 traces.
# 	Converted 1063002 traces.
# 	Converted 1064002 traces.
# 	Converted 1065002 traces.
# 	Converted 1066002 traces.
# 	Converted 1067002 traces.
# 	Converted 1068002 traces.
# 	Converted 1069002 traces.
# 	Converted 1070002 traces.
# 	Converted 1071002 traces.
# 	Converted 1072002 traces.
# 	Converted 1073002 traces.
# 	Converted 1074002 traces.
# 	Converted 1075002 traces.
# 	Converted 1076002 traces.
# 	Converted 1077002 traces.
# 	Converted 1078002 traces.
# 	Converted 1079002 traces.
# 	Converted 1080002 traces.
# 	Converted 1081002 traces.
# 	Converted 1082002 traces.
# 	Converted 1083002 traces.
# 	Converted 1084002 traces.
# 	Converted 1085002 traces.
# 	Converted 1086002 traces.
# 	Converted 1087002 traces.
# 	Converted 1088002 traces.
# 	Converted 1089002 traces.
# 	Converted 1090002 traces.
# 	Converted 1091002 traces.
# 	Converted 1092002 traces.
# 	Converted 1093002 traces.
# 	Converted 1094002 traces.
# 	Converted 1095002 traces.
# 	Converted 1096002 traces.
# 	Converted 1097002 traces.
# 	Converted 1098002 traces.
# 	Converted 1099002 traces.
# 	Converted 1100002 traces.
# 	Converted 1101002 traces.
# 	Converted 1102002 traces.
# 	Converted 1103002 traces.
# 	Converted 1104002 traces.
# 	Converted 1105002 traces.
# 	Converted 1106002 traces.
# 	Converted 1107002 traces.
# 	Converted 1108002 traces.
# 	Converted 1109002 traces.
# 	Converted 1110002 traces.
# 	Converted 1111002 traces.
# 	Converted 1112002 traces.
# 	Converted 1113002 traces.
# 	Converted 1114002 traces.
# 	Converted 1115002 traces.
# 	Converted 1116002 traces.
# 	Converted 1117002 traces.
# 	Converted 1118002 traces.
# 	Converted 1119002 traces.
# 	Converted 1120002 traces.
# 	Converted 1121002 traces.
# 	Converted 1122002 traces.
# 	Converted 1123002 traces.
# 	Converted 1124002 traces.
# 	Converted 1125002 traces.
# 	Converted 1126002 traces.
# 	Converted 1127002 traces.
# 	Converted 1128002 traces.
# 	Converted 1129002 traces.
# 	Converted 1130002 traces.
# 	Converted 1131002 traces.
# 	Converted 1132002 traces.
# 	Converted 1133002 traces.
# 	Converted 1134002 traces.
# 	Converted 1135002 traces.
# 	Converted 1136002 traces.
# 	Converted 1137002 traces.
# 	Converted 1138002 traces.
# 	Converted 1139002 traces.
# 	Converted 1140002 traces.
# 	Converted 1141002 traces.
# 	Converted 1142002 traces.
# 	Converted 1143002 traces.
# 	Converted 1144002 traces.
# 	Converted 1145002 traces.
# 	Converted 1146002 traces.
# 	Converted 1147002 traces.
# 	Converted 1148002 traces.
# 	Converted 1149002 traces.
# 	Converted 1150002 traces.
# 	Converted 1151002 traces.
# 	Converted 1152002 traces.
# 	Converted 1153002 traces.
# 	Converted 1154002 traces.
# 	Converted 1155002 traces.
# 	Converted 1156002 traces.
# 	Converted 1157002 traces.
# 	Converted 1158002 traces.
# 	Converted 1159002 traces.
# 	Converted 1160002 traces.
# 	Converted 1161002 traces.
# 	Converted 1162002 traces.
# 	Converted 1163002 traces.
# 	Converted 1164002 traces.
# 	Converted 1165002 traces.
# 	Converted 1166002 traces.
# 	Converted 1167002 traces.
# 	Converted 1168002 traces.
# 	Converted 1169002 traces.
# 	Converted 1170002 traces.
# 	Converted 1171002 traces.
# 	Converted 1172002 traces.
# 	Converted 1173002 traces.
# 	Converted 1174002 traces.
# 	Converted 1175002 traces.
# 	Converted 1176002 traces.
# 	Converted 1177002 traces.
# 	Converted 1178002 traces.
# 	Converted 1179002 traces.
# 	Converted 1180002 traces.
# 	Converted 1181002 traces.
# 	Converted 1182002 traces.
# 	Converted 1183002 traces.
# 	Converted 1184002 traces.
# 	Converted 1185002 traces.
# 	Converted 1186002 traces.
# 	Converted 1187002 traces.
# 	Converted 1188002 traces.
# 	Converted 1189002 traces.
# 	Converted 1190002 traces.
# 	Converted 1191002 traces.
# 	Converted 1192002 traces.
# 	Converted 1193002 traces.
# 	Converted 1194002 traces.
# 	Converted 1195002 traces.
# 	Converted 1196002 traces.
# 	Converted 1197002 traces.
# 	Converted 1198002 traces.
# 	Converted 1199002 traces.
# Batch written.. Total of 1200000 traces.
# 	Converted 1200002 traces.
# 	Converted 1201002 traces.
# 	Converted 1202002 traces.
# 	Converted 1203002 traces.
# 	Converted 1204002 traces.
# 	Converted 1205002 traces.
# 	Converted 1206002 traces.
# 	Converted 1207002 traces.
# 	Converted 1208002 traces.
# 	Converted 1209002 traces.
# 	Converted 1210002 traces.
# 	Converted 1211002 traces.
# 	Converted 1212002 traces.
# 	Converted 1213002 traces.
# 	Converted 1214002 traces.
# 	Converted 1215002 traces.
# 	Converted 1216002 traces.
# 	Converted 1217002 traces.
# 	Converted 1218002 traces.
# 	Converted 1219002 traces.
# 	Converted 1220002 traces.
# 	Converted 1221002 traces.
# 	Converted 1222002 traces.
# 	Converted 1223002 traces.
# 	Converted 1224002 traces.
# 	Converted 1225002 traces.
# 	Converted 1226002 traces.
# 	Converted 1227002 traces.
# 	Converted 1228002 traces.
# 	Converted 1229002 traces.
# 	Converted 1230002 traces.
# 	Converted 1231002 traces.
# 	Converted 1232002 traces.
# 	Converted 1233002 traces.
# 	Converted 1234002 traces.
# 	Converted 1235002 traces.
# 	Converted 1236002 traces.
# 	Converted 1237002 traces.
# 	Converted 1238002 traces.
# 	Converted 1239002 traces.
# 	Converted 1240002 traces.
# 	Converted 1241002 traces.
# 	Converted 1242002 traces.
# 	Converted 1243002 traces.
# 	Converted 1244002 traces.
# 	Converted 1245002 traces.
# 	Converted 1246002 traces.
# 	Converted 1247002 traces.
# 	Converted 1248002 traces.
# 	Converted 1249002 traces.
# 	Converted 1250002 traces.
# 	Converted 1251002 traces.
# 	Converted 1252002 traces.
# 	Converted 1253002 traces.
# 	Converted 1254002 traces.
# 	Converted 1255002 traces.
# 	Converted 1256002 traces.
# 	Converted 1257002 traces.
# 	Converted 1258002 traces.
# 	Converted 1259002 traces.
# 	Converted 1260002 traces.
# 	Converted 1261002 traces.
# 	Converted 1262002 traces.
# 	Converted 1263002 traces.
# 	Converted 1264002 traces.
# 	Converted 1265002 traces.
# 	Converted 1266002 traces.
# 	Converted 1267002 traces.
# 	Converted 1268002 traces.
# 	Converted 1269002 traces.
# 	Converted 1270002 traces.
# 	Converted 1271002 traces.
# 	Converted 1272002 traces.
# 	Converted 1273002 traces.
# 	Converted 1274002 traces.
# 	Converted 1275002 traces.
# 	Converted 1276002 traces.
# 	Converted 1277002 traces.
# 	Converted 1278002 traces.
# 	Converted 1279002 traces.
# 	Converted 1280002 traces.
# 	Converted 1281002 traces.
# 	Converted 1282002 traces.
# 	Converted 1283002 traces.
# 	Converted 1284002 traces.
# 	Converted 1285002 traces.
# 	Converted 1286002 traces.
# 	Converted 1287002 traces.
# 	Converted 1288002 traces.
# 	Converted 1289002 traces.
# 	Converted 1290002 traces.
# 	Converted 1291002 traces.
# 	Converted 1292002 traces.
# 	Converted 1293002 traces.
# 	Converted 1294002 traces.
# 	Converted 1295002 traces.
# 	Converted 1296002 traces.
# 	Converted 1297002 traces.
# 	Converted 1298002 traces.
# 	Converted 1299002 traces.
# 	Converted 1300002 traces.
# 	Converted 1301002 traces.
# 	Converted 1302002 traces.
# 	Converted 1303002 traces.
# 	Converted 1304002 traces.
# 	Converted 1305002 traces.
# 	Converted 1306002 traces.
# 	Converted 1307002 traces.
# 	Converted 1308002 traces.
# 	Converted 1309002 traces.
# 	Converted 1310002 traces.
# 	Converted 1311002 traces.
# 	Converted 1312002 traces.
# 	Converted 1313002 traces.
# 	Converted 1314002 traces.
# 	Converted 1315002 traces.
# 	Converted 1316002 traces.
# 	Converted 1317002 traces.
# 	Converted 1318002 traces.
# 	Converted 1319002 traces.
# 	Converted 1320002 traces.
# 	Converted 1321002 traces.
# 	Converted 1322002 traces.
# 	Converted 1323002 traces.
# 	Converted 1324002 traces.
# 	Converted 1325002 traces.
# 	Converted 1326002 traces.
# 	Converted 1327002 traces.
# 	Converted 1328002 traces.
# 	Converted 1329002 traces.
# 	Converted 1330002 traces.
# 	Converted 1331002 traces.
# 	Converted 1332002 traces.
# 	Converted 1333002 traces.
# 	Converted 1334002 traces.
# 	Converted 1335002 traces.
# 	Converted 1336002 traces.
# 	Converted 1337002 traces.
# 	Converted 1338002 traces.
# 	Converted 1339002 traces.
# 	Converted 1340002 traces.
# 	Converted 1341002 traces.
# 	Converted 1342002 traces.
# 	Converted 1343002 traces.
# 	Converted 1344002 traces.
# 	Converted 1345002 traces.
# 	Converted 1346002 traces.
# 	Converted 1347002 traces.
# 	Converted 1348002 traces.
# 	Converted 1349002 traces.
# 	Converted 1350002 traces.
# 	Converted 1351002 traces.
# 	Converted 1352002 traces.
# 	Converted 1353002 traces.
# 	Converted 1354002 traces.
# 	Converted 1355002 traces.
# 	Converted 1356002 traces.
# 	Converted 1357002 traces.
# 	Converted 1358002 traces.
# 	Converted 1359002 traces.
# 	Converted 1360002 traces.
# 	Converted 1361002 traces.
# 	Converted 1362002 traces.
# 	Converted 1363002 traces.
# 	Converted 1364002 traces.
# 	Converted 1365002 traces.
# 	Converted 1366002 traces.
# 	Converted 1367002 traces.
# 	Converted 1368002 traces.
# 	Converted 1369002 traces.
# 	Converted 1370002 traces.
# 	Converted 1371002 traces.
# 	Converted 1372002 traces.
# 	Converted 1373002 traces.
# 	Converted 1374002 traces.
# 	Converted 1375002 traces.
# 	Converted 1376002 traces.
# 	Converted 1377002 traces.
# 	Converted 1378002 traces.
# 	Converted 1379002 traces.
# 	Converted 1380002 traces.
# 	Converted 1381002 traces.
# 	Converted 1382002 traces.
# 	Converted 1383002 traces.
# 	Converted 1384002 traces.
# 	Converted 1385002 traces.
# 	Converted 1386002 traces.
# 	Converted 1387002 traces.
# 	Converted 1388002 traces.
# 	Converted 1389002 traces.
# 	Converted 1390002 traces.
# 	Converted 1391002 traces.
# 	Converted 1392002 traces.
# 	Converted 1393002 traces.
# 	Converted 1394002 traces.
# 	Converted 1395002 traces.
# 	Converted 1396002 traces.
# 	Converted 1397002 traces.
# 	Converted 1398002 traces.
# 	Converted 1399002 traces.
# 	Converted 1400002 traces.
# 	Converted 1401002 traces.
# 	Converted 1402002 traces.
# 	Converted 1403002 traces.
# 	Converted 1404002 traces.
# 	Converted 1405002 traces.
# 	Converted 1406002 traces.
# 	Converted 1407002 traces.
# 	Converted 1408002 traces.
# 	Converted 1409002 traces.
# 	Converted 1410002 traces.
# 	Converted 1411002 traces.
# 	Converted 1412002 traces.
# 	Converted 1413002 traces.
# 	Converted 1414002 traces.
# 	Converted 1415002 traces.
# 	Converted 1416002 traces.
# 	Converted 1417002 traces.
# 	Converted 1418002 traces.
# 	Converted 1419002 traces.
# 	Converted 1420002 traces.
# 	Converted 1421002 traces.
# 	Converted 1422002 traces.
# 	Converted 1423002 traces.
# 	Converted 1424002 traces.
# 	Converted 1425002 traces.
# 	Converted 1426002 traces.
# 	Converted 1427002 traces.
# 	Converted 1428002 traces.
# 	Converted 1429002 traces.
# 	Converted 1430002 traces.
# 	Converted 1431002 traces.
# 	Converted 1432002 traces.
# 	Converted 1433002 traces.
# 	Converted 1434002 traces.
# 	Converted 1435002 traces.
# 	Converted 1436002 traces.
# 	Converted 1437002 traces.
# 	Converted 1438002 traces.
# 	Converted 1439002 traces.
# 	Converted 1440002 traces.
# 	Converted 1441002 traces.
# 	Converted 1442002 traces.
# 	Converted 1443002 traces.
# 	Converted 1444002 traces.
# 	Converted 1445002 traces.
# 	Converted 1446002 traces.
# 	Converted 1447002 traces.
# 	Converted 1448002 traces.
# 	Converted 1449002 traces.
# 	Converted 1450002 traces.
# 	Converted 1451002 traces.
# 	Converted 1452002 traces.
# 	Converted 1453002 traces.
# 	Converted 1454002 traces.
# 	Converted 1455002 traces.
# 	Converted 1456002 traces.
# 	Converted 1457002 traces.
# 	Converted 1458002 traces.
# 	Converted 1459002 traces.
# 	Converted 1460002 traces.
# 	Converted 1461002 traces.
# 	Converted 1462002 traces.
# 	Converted 1463002 traces.
# 	Converted 1464002 traces.
# 	Converted 1465002 traces.
# 	Converted 1466002 traces.
# 	Converted 1467002 traces.
# 	Converted 1468002 traces.
# 	Converted 1469002 traces.
# 	Converted 1470002 traces.
# 	Converted 1471002 traces.
# 	Converted 1472002 traces.
# 	Converted 1473002 traces.
# 	Converted 1474002 traces.
# 	Converted 1475002 traces.
# 	Converted 1476002 traces.
# 	Converted 1477002 traces.
# 	Converted 1478002 traces.
# 	Converted 1479002 traces.
# 	Converted 1480002 traces.
# 	Converted 1481002 traces.
# 	Converted 1482002 traces.
# 	Converted 1483002 traces.
# 	Converted 1484002 traces.
# 	Converted 1485002 traces.
# 	Converted 1486002 traces.
# 	Converted 1487002 traces.
# 	Converted 1488002 traces.
# 	Converted 1489002 traces.
# 	Converted 1490002 traces.
# 	Converted 1491002 traces.
# 	Converted 1492002 traces.
# 	Converted 1493002 traces.
# 	Converted 1494002 traces.
# 	Converted 1495002 traces.
# 	Converted 1496002 traces.
# 	Converted 1497002 traces.
# 	Converted 1498002 traces.
# 	Converted 1499002 traces.
# Batch written.. Total of 1500000 traces.
# 	Converted 1500002 traces.
# 	Converted 1501002 traces.
# 	Converted 1502002 traces.
# 	Converted 1503002 traces.
# 	Converted 1504002 traces.
# 	Converted 1505002 traces.
# 	Converted 1506002 traces.
# 	Converted 1507002 traces.
# 	Converted 1508002 traces.
# 	Converted 1509002 traces.
# 	Converted 1510002 traces.
# 	Converted 1511002 traces.
# 	Converted 1512002 traces.
# 	Converted 1513002 traces.
# 	Converted 1514002 traces.
# 	Converted 1515002 traces.
# 	Converted 1516002 traces.
# 	Converted 1517002 traces.
# 	Converted 1518002 traces.
# 	Converted 1519002 traces.
# 	Converted 1520002 traces.
# 	Converted 1521002 traces.
# 	Converted 1522002 traces.
# 	Converted 1523002 traces.
# 	Converted 1524002 traces.
# 	Converted 1525002 traces.
# 	Converted 1526002 traces.
# 	Converted 1527002 traces.
# 	Converted 1528002 traces.
# 	Converted 1529002 traces.
# 	Converted 1530002 traces.
# 	Converted 1531002 traces.
# 	Converted 1532002 traces.
# 	Converted 1533002 traces.
# 	Converted 1534002 traces.
# 	Converted 1535002 traces.
# 	Converted 1536002 traces.
# 	Converted 1537002 traces.
# 	Converted 1538002 traces.
# 	Converted 1539002 traces.
# 	Converted 1540002 traces.
# 	Converted 1541002 traces.
# 	Converted 1542002 traces.
# 	Converted 1543002 traces.
# 	Converted 1544002 traces.
# 	Converted 1545002 traces.
# 	Converted 1546002 traces.
# 	Converted 1547002 traces.
# 	Converted 1548002 traces.
# 	Converted 1549002 traces.
# 	Converted 1550002 traces.
# 	Converted 1551002 traces.
# 	Converted 1552002 traces.
# 	Converted 1553002 traces.
# 	Converted 1554002 traces.
# 	Converted 1555002 traces.
# 	Converted 1556002 traces.
# 	Converted 1557002 traces.
# 	Converted 1558002 traces.
# 	Converted 1559002 traces.
# 	Converted 1560002 traces.
# 	Converted 1561002 traces.
# 	Converted 1562002 traces.
# 	Converted 1563002 traces.
# 	Converted 1564002 traces.
# 	Converted 1565002 traces.
# 	Converted 1566002 traces.
# 	Converted 1567002 traces.
# 	Converted 1568002 traces.
# 	Converted 1569002 traces.
# 	Converted 1570002 traces.
# 	Converted 1571002 traces.
# 	Converted 1572002 traces.
# 	Converted 1573002 traces.
# 	Converted 1574002 traces.
# 	Converted 1575002 traces.
# 	Converted 1576002 traces.
# 	Converted 1577002 traces.
# 	Converted 1578002 traces.
# 	Converted 1579002 traces.
# 	Converted 1580002 traces.
# 	Converted 1581002 traces.
# 	Converted 1582002 traces.
# 	Converted 1583002 traces.
# 	Converted 1584002 traces.
# 	Converted 1585002 traces.
# 	Converted 1586002 traces.
# 	Converted 1587002 traces.
# 	Converted 1588002 traces.
# 	Converted 1589002 traces.
# 	Converted 1590002 traces.
# 	Converted 1591002 traces.
# 	Converted 1592002 traces.
# 	Converted 1593002 traces.
# 	Converted 1594002 traces.
# 	Converted 1595002 traces.
# 	Converted 1596002 traces.
# 	Converted 1597002 traces.
# 	Converted 1598002 traces.
# 	Converted 1599002 traces.
# 	Converted 1600002 traces.
# 	Converted 1601002 traces.
# 	Converted 1602002 traces.
# 	Converted 1603002 traces.
# 	Converted 1604002 traces.
# 	Converted 1605002 traces.
# 	Converted 1606002 traces.
# 	Converted 1607002 traces.
# 	Converted 1608002 traces.
# 	Converted 1609002 traces.
# 	Converted 1610002 traces.
# 	Converted 1611002 traces.
# 	Converted 1612002 traces.
# 	Converted 1613002 traces.
# 	Converted 1614002 traces.
# 	Converted 1615002 traces.
# 	Converted 1616002 traces.
# 	Converted 1617002 traces.
# 	Converted 1618002 traces.
# 	Converted 1619002 traces.
# 	Converted 1620002 traces.
# 	Converted 1621002 traces.
# 	Converted 1622002 traces.
# 	Converted 1623002 traces.
# 	Converted 1624002 traces.
# 	Converted 1625002 traces.
# 	Converted 1626002 traces.
# 	Converted 1627002 traces.
# 	Converted 1628002 traces.
# 	Converted 1629002 traces.
# 	Converted 1630002 traces.
# 	Converted 1631002 traces.
# 	Converted 1632002 traces.
# 	Converted 1633002 traces.
# 	Converted 1634002 traces.
# 	Converted 1635002 traces.
# 	Converted 1636002 traces.
# 	Converted 1637002 traces.
# 	Converted 1638002 traces.
# 	Converted 1639002 traces.
# 	Converted 1640002 traces.
# 	Converted 1641002 traces.
# 	Converted 1642002 traces.
# 	Converted 1643002 traces.
# 	Converted 1644002 traces.
# 	Converted 1645002 traces.
# 	Converted 1646002 traces.
# 	Converted 1647002 traces.
# 	Converted 1648002 traces.
# 	Converted 1649002 traces.
# 	Converted 1650002 traces.
# 	Converted 1651002 traces.
# 	Converted 1652002 traces.
# 	Converted 1653002 traces.
# 	Converted 1654002 traces.
# 	Converted 1655002 traces.
# 	Converted 1656002 traces.
# 	Converted 1657002 traces.
# 	Converted 1658002 traces.
# 	Converted 1659002 traces.
# 	Converted 1660002 traces.
# 	Converted 1661002 traces.
# 	Converted 1662002 traces.
# 	Converted 1663002 traces.
# 	Converted 1664002 traces.
# 	Converted 1665002 traces.
# 	Converted 1666002 traces.
# 	Converted 1667002 traces.
# 	Converted 1668002 traces.
# 	Converted 1669002 traces.
# 	Converted 1670002 traces.
# 	Converted 1671002 traces.
# 	Converted 1672002 traces.
# 	Converted 1673002 traces.
# 	Converted 1674002 traces.
# 	Converted 1675002 traces.
# 	Converted 1676002 traces.
# 	Converted 1677002 traces.
# 	Converted 1678002 traces.
# 	Converted 1679002 traces.
# 	Converted 1680002 traces.
# 	Converted 1681002 traces.
# 	Converted 1682002 traces.
# 	Converted 1683002 traces.
# 	Converted 1684002 traces.
# 	Converted 1685002 traces.
# 	Converted 1686002 traces.
# 	Converted 1687002 traces.
# 	Converted 1688002 traces.
# 	Converted 1689002 traces.
# 	Converted 1690002 traces.
# 	Converted 1691002 traces.
# 	Converted 1692002 traces.
# 	Converted 1693002 traces.
# 	Converted 1694002 traces.
# 	Converted 1695002 traces.
# 	Converted 1696002 traces.
# 	Converted 1697002 traces.
# 	Converted 1698002 traces.
# 	Converted 1699002 traces.
# 	Converted 1700002 traces.
# 	Converted 1701002 traces.
# 	Converted 1702002 traces.
# 	Converted 1703002 traces.
# 	Converted 1704002 traces.
# 	Converted 1705002 traces.
# 	Converted 1706002 traces.
# 	Converted 1707002 traces.
# 	Converted 1708002 traces.
# 	Converted 1709002 traces.
# 	Converted 1710002 traces.
# 	Converted 1711002 traces.
# 	Converted 1712002 traces.
# 	Converted 1713002 traces.
# 	Converted 1714002 traces.
# 	Converted 1715002 traces.
# 	Converted 1716002 traces.
# 	Converted 1717002 traces.
# 	Converted 1718002 traces.
# 	Converted 1719002 traces.
# 	Converted 1720002 traces.
# 	Converted 1721002 traces.
# 	Converted 1722002 traces.
# 	Converted 1723002 traces.
# 	Converted 1724002 traces.
# 	Converted 1725002 traces.
# 	Converted 1726002 traces.
# 	Converted 1727002 traces.
# 	Converted 1728002 traces.
# 	Converted 1729002 traces.
# 	Converted 1730002 traces.
# 	Converted 1731002 traces.
# 	Converted 1732002 traces.
# 	Converted 1733002 traces.
# 	Converted 1734002 traces.
# 	Converted 1735002 traces.
# 	Converted 1736002 traces.
# 	Converted 1737002 traces.
# 	Converted 1738002 traces.
# 	Converted 1739002 traces.
# 	Converted 1740002 traces.
# 	Converted 1741002 traces.
# 	Converted 1742002 traces.
# 	Converted 1743002 traces.
# 	Converted 1744002 traces.
# 	Converted 1745002 traces.
# 	Converted 1746002 traces.
# 	Converted 1747002 traces.
# 	Converted 1748002 traces.
# 	Converted 1749002 traces.
# 	Converted 1750002 traces.
# 	Converted 1751002 traces.
# 	Converted 1752002 traces.
# 	Converted 1753002 traces.
# 	Converted 1754002 traces.
# 	Converted 1755002 traces.
# 	Converted 1756002 traces.
# 	Converted 1757002 traces.
# 	Converted 1758002 traces.
# 	Converted 1759002 traces.
# 	Converted 1760002 traces.
# 	Converted 1761002 traces.
# 	Converted 1762002 traces.
# 	Converted 1763002 traces.
# 	Converted 1764002 traces.
# 	Converted 1765002 traces.
# 	Converted 1766002 traces.
# 	Converted 1767002 traces.
# 	Converted 1768002 traces.
# 	Converted 1769002 traces.
# 	Converted 1770002 traces.
# 	Converted 1771002 traces.
# 	Converted 1772002 traces.
# 	Converted 1773002 traces.
# 	Converted 1774002 traces.
# 	Converted 1775002 traces.
# 	Converted 1776002 traces.
# 	Converted 1777002 traces.
# 	Converted 1778002 traces.
# 	Converted 1779002 traces.
# 	Converted 1780002 traces.
# 	Converted 1781002 traces.
# 	Converted 1782002 traces.
# 	Converted 1783002 traces.
# 	Converted 1784002 traces.
# 	Converted 1785002 traces.
# 	Converted 1786002 traces.
# 	Converted 1787002 traces.
# 	Converted 1788002 traces.
# 	Converted 1789002 traces.
# 	Converted 1790002 traces.
# 	Converted 1791002 traces.
# 	Converted 1792002 traces.
# 	Converted 1793002 traces.
# 	Converted 1794002 traces.
# 	Converted 1795002 traces.
# 	Converted 1796002 traces.
# 	Converted 1797002 traces.
# 	Converted 1798002 traces.
# 	Converted 1799002 traces.
# Batch written.. Total of 1800000 traces.
# 	Converted 1800002 traces.
# 	Converted 1801002 traces.
# 	Converted 1802002 traces.
# 	Converted 1803002 traces.
# 	Converted 1804002 traces.
# 	Converted 1805002 traces.
# 	Converted 1806002 traces.
# 	Converted 1807002 traces.
# 	Converted 1808002 traces.
# 	Converted 1809002 traces.
# ...
# 	Converted 1943002 traces.
# 	Converted 1944002 traces.
# 	Converted 1945002 traces.
# 	Converted 1946002 traces.
# 	Converted 1947002 traces.
# 	Converted 1948002 traces.
# 	Converted 1949002 traces.
# 	Converted 1950002 traces.
# 	Converted 1951002 traces.
# 	Converted 1952002 traces.
# 	Converted 1953002 traces.
# 	Converted 1954002 traces.
# 	Converted 1955002 traces.
# 	Converted 1956002 traces.
# 	Converted 1957002 traces.
# 	Converted 1958002 traces.
# 	Converted 1959002 traces.
# 	Converted 1960002 traces.
# 	Converted 1961002 traces.
# 	Converted 1962002 traces.
# 	Converted 1963002 traces.
# 	Converted 1964002 traces.
# 	Converted 1965002 traces.
# 	Converted 1966002 traces.
# 	Converted 1967002 traces.
# 	Converted 1968002 traces.
# 	Converted 1969002 traces.
# 	Converted 1970002 traces.
# 	Converted 1971002 traces.
# 	Converted 1972002 traces.
# 	Converted 1973002 traces.
# 	Converted 1974002 traces.
# 	Converted 1975002 traces.
# 	Converted 1976002 traces.
# 	Converted 1977002 traces.
# 	Converted 1978002 traces.
# 	Converted 1979002 traces.
# 	Converted 1980002 traces.
# 	Converted 1981002 traces.
# 	Converted 1982002 traces.
# 	Converted 1983002 traces.
# 	Converted 1984002 traces.
# 	Converted 1985002 traces.
# 	Converted 1986002 traces.
# 	Converted 1987002 traces.
# 	Converted 1988002 traces.
# 	Converted 1989002 traces.
# 	Converted 1990002 traces.
# 	Converted 1991002 traces.
# 	Converted 1992002 traces.
# 	Converted 1993002 traces.
# 	Converted 1994002 traces.
# 	Converted 1995002 traces.
# 	Converted 1996002 traces.
# 	Converted 1997002 traces.
# 	Converted 1998002 traces.
# 	Converted 1999002 traces.
# 	Converted 2000002 traces.
# 	Converted 2001002 traces.
# 	Converted 2002002 traces.
# 	Converted 2003002 traces.
# 	Converted 2004002 traces.
# 	Converted 2005002 traces.
# 	Converted 2006002 traces.
# 	Converted 2007002 traces.
# 	Converted 2008002 traces.
# 	Converted 2009002 traces.
# 	Converted 2010002 traces.
# 	Converted 2011002 traces.
# 	Converted 2012002 traces.
# 	Converted 2013002 traces.
# 	Converted 2014002 traces.
# 	Converted 2015002 traces.
# 	Converted 2016002 traces.
# 	Converted 2017002 traces.
# 	Converted 2018002 traces.
# 	Converted 2019002 traces.
# 	Converted 2020002 traces.
# 	Converted 2021002 traces.
# 	Converted 2022002 traces.
# 	Converted 2023002 traces.
# 	Converted 2024002 traces.
# 	Converted 2025002 traces.
# 	Converted 2026002 traces.
# 	Converted 2027002 traces.
# 	Converted 2028002 traces.
# 	Converted 2029002 traces.
# 	Converted 2030002 traces.
# 	Converted 2031002 traces.
# 	Converted 2032002 traces.
# 	Converted 2033002 traces.
# 	Converted 2034002 traces.
# 	Converted 2035002 traces.
# 	Converted 2036002 traces.
# 	Converted 2037002 traces.
# 	Converted 2038002 traces.
# 	Converted 2039002 traces.
# 	Converted 2040002 traces.
# 	Converted 2041002 traces.
# 	Converted 2042002 traces.
# 	Converted 2043002 traces.
# 	Converted 2044002 traces.
# 	Converted 2045002 traces.
# 	Converted 2046002 traces.
# 	Converted 2047002 traces.
# 	Converted 2048002 traces.
# 	Converted 2049002 traces.
# 	Converted 2050002 traces.
# 	Converted 2051002 traces.
# 	Converted 2052002 traces.
# 	Converted 2053002 traces.
# 	Converted 2054002 traces.
# 	Converted 2055002 traces.
# 	Converted 2056002 traces.
# 	Converted 2057002 traces.
# 	Converted 2058002 traces.
# 	Converted 2059002 traces.
# 	Converted 2060002 traces.
# 	Converted 2061002 traces.
# 	Converted 2062002 traces.
# 	Converted 2063002 traces.
# 	Converted 2064002 traces.
# 	Converted 2065002 traces.
# 	Converted 2066002 traces.
# 	Converted 2067002 traces.
# 	Converted 2068002 traces.
# 	Converted 2069002 traces.
# 	Converted 2070002 traces.
# 	Converted 2071002 traces.
# 	Converted 2072002 traces.
# 	Converted 2073002 traces.
# 	Converted 2074002 traces.
# 	Converted 2075002 traces.
# 	Converted 2076002 traces.
# 	Converted 2077002 traces.
# 	Converted 2078002 traces.
# 	Converted 2079002 traces.
# 	Converted 2080002 traces.
# 	Converted 2081002 traces.
# 	Converted 2082002 traces.
# 	Converted 2083002 traces.
# 	Converted 2084002 traces.
# 	Converted 2085002 traces.
# 	Converted 2086002 traces.
# 	Converted 2087002 traces.
# 	Converted 2088002 traces.
# 	Converted 2089002 traces.
# 	Converted 2090002 traces.
# 	Converted 2091002 traces.
# 	Converted 2092002 traces.
# 	Converted 2093002 traces.
# 	Converted 2094002 traces.
# 	Converted 2095002 traces.
# 	Converted 2096002 traces.
# 	Converted 2097002 traces.
# 	Converted 2098002 traces.
# 	Converted 2099002 traces.
# Batch written.. Total of 2100000 traces.
# 	Converted 2100002 traces.
# 	Converted 2101002 traces.
# 	Converted 2102002 traces.
# 	Converted 2103002 traces.
# 	Converted 2104002 traces.
# 	Converted 2105002 traces.
# 	Converted 2106002 traces.
# 	Converted 2107002 traces.
# 	Converted 2108002 traces.
# 	Converted 2109002 traces.
# 	Converted 2110002 traces.
# 	Converted 2111002 traces.
# 	Converted 2112002 traces.
# 	Converted 2113002 traces.
# 	Converted 2114002 traces.
# 	Converted 2115002 traces.
# 	Converted 2116002 traces.
# 	Converted 2117002 traces.
# 	Converted 2118002 traces.
# 	Converted 2119002 traces.
# 	Converted 2120002 traces.
# 	Converted 2121002 traces.
# 	Converted 2122002 traces.
# 	Converted 2123002 traces.
# 	Converted 2124002 traces.
# 	Converted 2125002 traces.
# 	Converted 2126002 traces.
# 	Converted 2127002 traces.
# 	Converted 2128002 traces.
# 	Converted 2129002 traces.
# 	Converted 2130002 traces.
# 	Converted 2131002 traces.
# 	Converted 2132002 traces.
# 	Converted 2133002 traces.
# 	Converted 2134002 traces.
# 	Converted 2135002 traces.
# 	Converted 2136002 traces.
# 	Converted 2137002 traces.
# 	Converted 2138002 traces.
# 	Converted 2139002 traces.
# 	Converted 2140002 traces.
# 	Converted 2141002 traces.
# 	Converted 2142002 traces.
# 	Converted 2143002 traces.
# 	Converted 2144002 traces.
# 	Converted 2145002 traces.
# 	Converted 2146002 traces.
# 	Converted 2147002 traces.
# 	Converted 2148002 traces.
# 	Converted 2149002 traces.
# 	Converted 2150002 traces.
# 	Converted 2151002 traces.
# 	Converted 2152002 traces.
# 	Converted 2153002 traces.
# 	Converted 2154002 traces.
# 	Converted 2155002 traces.
# 	Converted 2156002 traces.
# 	Converted 2157002 traces.
# 	Converted 2158002 traces.
# 	Converted 2159002 traces.
# 	Converted 2160002 traces.
# 	Converted 2161002 traces.
# 	Converted 2162002 traces.
# 	Converted 2163002 traces.
# 	Converted 2164002 traces.
# 	Converted 2165002 traces.
# 	Converted 2166002 traces.
# 	Converted 2167002 traces.
# 	Converted 2168002 traces.
# 	Converted 2169002 traces.
# 	Converted 2170002 traces.
# 	Converted 2171002 traces.
# 	Converted 2172002 traces.
# 	Converted 2173002 traces.
# 	Converted 2174002 traces.
# 	Converted 2175002 traces.
# 	Converted 2176002 traces.
# 	Converted 2177002 traces.
# 	Converted 2178002 traces.
# 	Converted 2179002 traces.
# 	Converted 2180002 traces.
# 	Converted 2181002 traces.
# 	Converted 2182002 traces.
# 	Converted 2183002 traces.
# 	Converted 2184002 traces.
# 	Converted 2185002 traces.
# 	Converted 2186002 traces.
# 	Converted 2187002 traces.
# 	Converted 2188002 traces.
# 	Converted 2189002 traces.
# 	Converted 2190002 traces.
# 	Converted 2191002 traces.
# 	Converted 2192002 traces.
# 	Converted 2193002 traces.
# 	Converted 2194002 traces.
# 	Converted 2195002 traces.
# 	Converted 2196002 traces.
# 	Converted 2197002 traces.
# 	Converted 2198002 traces.
# 	Converted 2199002 traces.
# 	Converted 2200002 traces.
# 	Converted 2201002 traces.
# 	Converted 2202002 traces.
# 	Converted 2203002 traces.
# 	Converted 2204002 traces.
# 	Converted 2205002 traces.
# 	Converted 2206002 traces.
# 	Converted 2207002 traces.
# 	Converted 2208002 traces.
# 	Converted 2209002 traces.
# 	Converted 2210002 traces.
# 	Converted 2211002 traces.
# 	Converted 2212002 traces.
# 	Converted 2213002 traces.
# 	Converted 2214002 traces.
# 	Converted 2215002 traces.
# 	Converted 2216002 traces.
# 	Converted 2217002 traces.
# 	Converted 2218002 traces.
# 	Converted 2219002 traces.
# 	Converted 2220002 traces.
# 	Converted 2221002 traces.
# 	Converted 2222002 traces.
# 	Converted 2223002 traces.
# 	Converted 2224002 traces.
# 	Converted 2225002 traces.
# 	Converted 2226002 traces.
# 	Converted 2227002 traces.
# 	Converted 2228002 traces.
# 	Converted 2229002 traces.
# 	Converted 2230002 traces.
# 	Converted 2231002 traces.
# 	Converted 2232002 traces.
# 	Converted 2233002 traces.
# 	Converted 2234002 traces.
# 	Converted 2235002 traces.
# 	Converted 2236002 traces.
# 	Converted 2237002 traces.
# 	Converted 2238002 traces.
# 	Converted 2239002 traces.
# 	Converted 2240002 traces.
# 	Converted 2241002 traces.
# 	Converted 2242002 traces.
# 	Converted 2243002 traces.
# 	Converted 2244002 traces.
# 	Converted 2245002 traces.
# 	Converted 2246002 traces.
# 	Converted 2247002 traces.
# 	Converted 2248002 traces.
# 	Converted 2249002 traces.
# 	Converted 2250002 traces.
# 	Converted 2251002 traces.
# 	Converted 2252002 traces.
# 	Converted 2253002 traces.
# 	Converted 2254002 traces.
# 	Converted 2255002 traces.
# 	Converted 2256002 traces.
# 	Converted 2257002 traces.
# 	Converted 2258002 traces.
# 	Converted 2259002 traces.
# 	Converted 2260002 traces.
# 	Converted 2261002 traces.
# 	Converted 2262002 traces.
# 	Converted 2263002 traces.
# 	Converted 2264002 traces.
# 	Converted 2265002 traces.
# 	Converted 2266002 traces.
# 	Converted 2267002 traces.
# 	Converted 2268002 traces.
# 	Converted 2269002 traces.
# 	Converted 2270002 traces.
# 	Converted 2271002 traces.
# 	Converted 2272002 traces.
# 	Converted 2273002 traces.
# 	Converted 2274002 traces.
# 	Converted 2275002 traces.
# 	Converted 2276002 traces.
# 	Converted 2277002 traces.
# 	Converted 2278002 traces.
# 	Converted 2279002 traces.
# 	Converted 2280002 traces.
# 	Converted 2281002 traces.
# 	Converted 2282002 traces.
# 	Converted 2283002 traces.
# 	Converted 2284002 traces.
# 	Converted 2285002 traces.
# 	Converted 2286002 traces.
# 	Converted 2287002 traces.
# 	Converted 2288002 traces.
# 	Converted 2289002 traces.
# 	Converted 2290002 traces.
# 	Converted 2291002 traces.
# 	Converted 2292002 traces.
# 	Converted 2293002 traces.
# 	Converted 2294002 traces.
# 	Converted 2295002 traces.
# 	Converted 2296002 traces.
# 	Converted 2297002 traces.
# 	Converted 2298002 traces.
# 	Converted 2299002 traces.
# 	Converted 2300002 traces.
# 	Converted 2301002 traces.
# 	Converted 2302002 traces.
# 	Converted 2303002 traces.
# 	Converted 2304002 traces.
# 	Converted 2305002 traces.
# 	Converted 2306002 traces.
# 	Converted 2307002 traces.
# 	Converted 2308002 traces.
# 	Converted 2309002 traces.
# 	Converted 2310002 traces.
# 	Converted 2311002 traces.
# 	Converted 2312002 traces.
# 	Converted 2313002 traces.
# 	Converted 2314002 traces.
# 	Converted 2315002 traces.
# 	Converted 2316002 traces.
# 	Converted 2317002 traces.
# 	Converted 2318002 traces.
# 	Converted 2319002 traces.
# 	Converted 2320002 traces.
# 	Converted 2321002 traces.
# 	Converted 2322002 traces.
# 	Converted 2323002 traces.
# 	Converted 2324002 traces.
# 	Converted 2325002 traces.
# 	Converted 2326002 traces.
# 	Converted 2327002 traces.
# 	Converted 2328002 traces.
# 	Converted 2329002 traces.
# 	Converted 2330002 traces.
# 	Converted 2331002 traces.
# 	Converted 2332002 traces.
# 	Converted 2333002 traces.
# 	Converted 2334002 traces.
# 	Converted 2335002 traces.
# 	Converted 2336002 traces.
# 	Converted 2337002 traces.
# 	Converted 2338002 traces.
# 	Converted 2339002 traces.
# 	Converted 2340002 traces.
# 	Converted 2341002 traces.
# 	Converted 2342002 traces.
# 	Converted 2343002 traces.
# 	Converted 2344002 traces.
# 	Converted 2345002 traces.
# 	Converted 2346002 traces.
# 	Converted 2347002 traces.
# 	Converted 2348002 traces.
# 	Converted 2349002 traces.
# 	Converted 2350002 traces.
# 	Converted 2351002 traces.
# 	Converted 2352002 traces.
# 	Converted 2353002 traces.
# 	Converted 2354002 traces.
# 	Converted 2355002 traces.
# 	Converted 2356002 traces.
# 	Converted 2357002 traces.
# 	Converted 2358002 traces.
# 	Converted 2359002 traces.
# 	Converted 2360002 traces.
# 	Converted 2361002 traces.
# 	Converted 2362002 traces.
# 	Converted 2363002 traces.
# 	Converted 2364002 traces.
# 	Converted 2365002 traces.
# 	Converted 2366002 traces.
# 	Converted 2367002 traces.
# 	Converted 2368002 traces.
# 	Converted 2369002 traces.
# 	Converted 2370002 traces.
# 	Converted 2371002 traces.
# 	Converted 2372002 traces.
# 	Converted 2373002 traces.
# 	Converted 2374002 traces.
# 	Converted 2375002 traces.
# 	Converted 2376002 traces.
# 	Converted 2377002 traces.
# 	Converted 2378002 traces.
# 	Converted 2379002 traces.
# 	Converted 2380002 traces.
# 	Converted 2381002 traces.
# 	Converted 2382002 traces.
# 	Converted 2383002 traces.
# 	Converted 2384002 traces.
# 	Converted 2385002 traces.
# 	Converted 2386002 traces.
# 	Converted 2387002 traces.
# 	Converted 2388002 traces.
# 	Converted 2389002 traces.
# 	Converted 2390002 traces.
# 	Converted 2391002 traces.
# 	Converted 2392002 traces.
# 	Converted 2393002 traces.
# 	Converted 2394002 traces.
# 	Converted 2395002 traces.
# 	Converted 2396002 traces.
# 	Converted 2397002 traces.
# 	Converted 2398002 traces.
# 	Converted 2399002 traces.
# Batch written.. Total of 2400000 traces.
# 	Converted 2400002 traces.
# 	Converted 2401002 traces.
# 	Converted 2402002 traces.
# 	Converted 2403002 traces.
# 	Converted 2404002 traces.
# 	Converted 2405002 traces.
# 	Converted 2406002 traces.
# 	Converted 2407002 traces.
# 	Converted 2408002 traces.
# 	Converted 2409002 traces.
# 	Converted 2410002 traces.
# 	Converted 2411002 traces.
# 	Converted 2412002 traces.
# 	Converted 2413002 traces.
# 	Converted 2414002 traces.
# 	Converted 2415002 traces.
# 	Converted 2416002 traces.
# 	Converted 2417002 traces.
# 	Converted 2418002 traces.
# 	Converted 2419002 traces.
# 	Converted 2420002 traces.
# 	Converted 2421002 traces.
# 	Converted 2422002 traces.
# 	Converted 2423002 traces.
# 	Converted 2424002 traces.
# 	Converted 2425002 traces.
# 	Converted 2426002 traces.
# 	Converted 2427002 traces.
# 	Converted 2428002 traces.
# 	Converted 2429002 traces.
# 	Converted 2430002 traces.
# 	Converted 2431002 traces.
# 	Converted 2432002 traces.
# 	Converted 2433002 traces.
# 	Converted 2434002 traces.
# 	Converted 2435002 traces.
# 	Converted 2436002 traces.
# 	Converted 2437002 traces.
# 	Converted 2438002 traces.
# 	Converted 2439002 traces.
# 	Converted 2440002 traces.
# 	Converted 2441002 traces.
# 	Converted 2442002 traces.
# 	Converted 2443002 traces.
# 	Converted 2444002 traces.
# 	Converted 2445002 traces.
# 	Converted 2446002 traces.
# 	Converted 2447002 traces.
# 	Converted 2448002 traces.
# 	Converted 2449002 traces.
# 	Converted 2450002 traces.
# 	Converted 2451002 traces.
# 	Converted 2452002 traces.
# 	Converted 2453002 traces.
# 	Converted 2454002 traces.
# 	Converted 2455002 traces.
# 	Converted 2456002 traces.
# 	Converted 2457002 traces.
# 	Converted 2458002 traces.
# 	Converted 2459002 traces.
# 	Converted 2460002 traces.
# 	Converted 2461002 traces.
# 	Converted 2462002 traces.
# 	Converted 2463002 traces.
# 	Converted 2464002 traces.
# 	Converted 2465002 traces.
# 	Converted 2466002 traces.
# 	Converted 2467002 traces.
# 	Converted 2468002 traces.
# 	Converted 2469002 traces.
# 	Converted 2470002 traces.
# 	Converted 2471002 traces.
# 	Converted 2472002 traces.
# 	Converted 2473002 traces.
# 	Converted 2474002 traces.
# 	Converted 2475002 traces.
# 	Converted 2476002 traces.
# 	Converted 2477002 traces.
# 	Converted 2478002 traces.
# 	Converted 2479002 traces.
# 	Converted 2480002 traces.
# 	Converted 2481002 traces.
# 	Converted 2482002 traces.
# 	Converted 2483002 traces.
# 	Converted 2484002 traces.
# 	Converted 2485002 traces.
# 	Converted 2486002 traces.
# 	Converted 2487002 traces.
# 	Converted 2488002 traces.
# 	Converted 2489002 traces.
# 	Converted 2490002 traces.
# 	Converted 2491002 traces.
# 	Converted 2492002 traces.
# 	Converted 2493002 traces.
# 	Converted 2494002 traces.
# 	Converted 2495002 traces.
# 	Converted 2496002 traces.
# 	Converted 2497002 traces.
# 	Converted 2498002 traces.
# 	Converted 2499002 traces.
# 	Converted 2500002 traces.
# 	Converted 2501002 traces.
# 	Converted 2502002 traces.
# 	Converted 2503002 traces.
# 	Converted 2504002 traces.
# 	Converted 2505002 traces.
# 	Converted 2506002 traces.
# 	Converted 2507002 traces.
# 	Converted 2508002 traces.
# 	Converted 2509002 traces.
# 	Converted 2510002 traces.
# 	Converted 2511002 traces.
# 	Converted 2512002 traces.
# 	Converted 2513002 traces.
# 	Converted 2514002 traces.
# 	Converted 2515002 traces.
# 	Converted 2516002 traces.
# 	Converted 2517002 traces.
# 	Converted 2518002 traces.
# 	Converted 2519002 traces.
# 	Converted 2520002 traces.
# 	Converted 2521002 traces.
# 	Converted 2522002 traces.
# 	Converted 2523002 traces.
# 	Converted 2524002 traces.
# 	Converted 2525002 traces.
# 	Converted 2526002 traces.
# 	Converted 2527002 traces.
# 	Converted 2528002 traces.
# 	Converted 2529002 traces.
# 	Converted 2530002 traces.
# 	Converted 2531002 traces.

# %%
dataset.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11112/46347760.py in <module>
# ----> 1 dataset.close()
#
# AttributeError: 'Group' object has no attribute 'close'
